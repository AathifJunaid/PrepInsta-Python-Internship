# %% [markdown]
# # Hangman Game Week 02
#
# How Hangman Game works: https://en.wikipedia.org/wiki/Hangman_(game)
#
# Play Hangman Game with Friends: https://hangmanwordgame.com/?fca=1&success=0#/

# %% [markdown]
# # Step 1

# %%
word_list = ["prepinsta", "prime", "mohan"]

# TODO-1 - Randomly choose a word from the word_list and assign it to a variable called chosen_word.

# TODO-2 - Ask the user to guess a letter and assign their answer to a variable called guess. Make guess lowercase.

# TODO-3 - Check if the letter the user guessed (guess) is one of the letters in the chosen_word.

# %%
import random as rn

words = "Reading books stories adventures forests mysteries everyday life journey chair animals robots faraway lands helps learn new things use imagination fun learn time"

words.lower()

word_list = words.split()

chosen_word = rn.choice(word_list)

print(chosen_word)

n = len(chosen_word)
# Out:
# books

# %% [markdown]
# # Step 02

# %%
#Step 2

# include Step 01 Solution



#TODO-1: - Create an empty List called display.
#For each letter in the chosen_word, add a "_" to 'display'.
#So if the chosen_word was "mohan", display should be ["_", "_", "_", "_", "_"] with 5 "_" representing each letter to guess.



#TODO-2: - Loop through each position in the chosen_word;
#If the letter at that position matches 'guess' then reveal that letter in the display at that position.
#e.g. If the user guessed "a" and the chosen word was "mohan", then display should be ["_", "_", "_", "a", "_"].




#TODO-3: - Print 'display' and you should see the guessed letter in the correct position and every other letter replace with "_".
#Hint - Don't worry about getting the user to guess the next letter. We'll tackle that in step 3.

# %%
display = []

for i in range (len(chosen_word)):
  display.append("_")

print(display)


###guess = input("Make a guess:")

###for i in range(0,n):
#  if(guess==chosen_word[i]):
#   display[i]=guess

#print(display)
# Out:
# ['_', '_', '_', '_', '_']

# %% [markdown]
# # Step 03

# %%
#Step 3

# Step 02 code integration with while loop

#TODO-1: - Use a while loop to let the user guess again.
#The loop should only stop once the user has guessed all the letters in the chosen_word and 'display' has no more blanks ("_").
#Then you can tell the user they've won.

# %%
while True:


  guess = input("Make a guess:").lower()

  for i in range(len(chosen_word)):
    if(guess==chosen_word[i]):
      display[i]=guess


  print(display)


  if("_" not in display):
    break


print("You have guessed the word correctly!! You Win!!")
# Out:
# Make a guess:e
# ['e', 'v', 'e', 'r', 'y', 'd', 'a', 'y']
# You have guessed the word correctly!! You Win!!

# %% [markdown]
# # Step 04

# %%
#Step 4


#TODO-1: - Create a variable called 'lives' to keep track of the number of lives left.
#Set 'lives' to equal 6.



#TODO-2: - If guess is not a letter in the chosen_word,
#Then reduce 'lives' by 1.
#If lives goes down to 0 then the game should stop and it should print "You lose."

# %%
global lives

while True:

  lives = 6


  guess = input("Make a guess:").lower()

  for i in range(len(chosen_word)):
    if(guess==chosen_word[i]):
      display[i]=guess



  if(guess not in chosen_word):
    print("You've got it wrong,Try Again")
    lives -= 1
    print("You are left with",lives,"chances")



  if(lives == 0):
    print("You have run out of lives, You loose")
    break


  print(display)


  if("_" not in display):
    print("You have guessed the word correctly!! You Win!!")
    break
# Out:
# Make a guess:k
# ['_', '_', '_', 'k', '_']
# Make a guess:s
# ['_', '_', '_', 'k', 's']
# Make a guess:x
# You've got it wrong,Try Again
# You are left with 5 chances
# ['_', '_', '_', 'k', 's']
# Make a guess:n
# You've got it wrong,Try Again
# You are left with 5 chances
# ['_', '_', '_', 'k', 's']
# Make a guess:z
# You've got it wrong,Try Again
# You are left with 5 chances
# ['_', '_', '_', 'k', 's']
# Make a guess:o
# ['_', 'o', 'o', 'k', 's']
# Make a guess:z
# You've got it wrong,Try Again
# You are left with 5 chances
# ['_', 'o', 'o', 'k', 's']
# Make a guess:c
# You've got it wrong,Try Again
# You are left with 5 chances
# ['_', 'o', 'o', 'k', 's']
# Make a guess:b
# ['b', 'o', 'o', 'k', 's']
# You have guessed the word correctly!! You Win!!

# %% [markdown]
# # Step 05
#
# Complete Code

# %%
# Your Code

import random as rn

words = "Reading books stories adventures forests mysteries everyday life journey chair animals robots faraway lands helps learn new things use imagination fun learn time"


word_list = words.split()

chosen_word = rn.choice(word_list)

chosen_word = chosen_word.lower()


display = []

hangman = ['''
  +---+
  |   |
      |
      |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
      |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
  |   |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
 /|   |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
 /|\  |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
 /|\  |
 /    |
      |
=========''', '''
  +---+
  |   |
  O   |
 /|\  |
 / \  |
      |
=========''']

for i in range (len(chosen_word)):
  display.append("_")

print(display)

lives = 6
art = 0

while True:

  guess = input("Make a guess:")
  guess = guess.lower()

  for i in range(len(chosen_word)):
    if(guess==chosen_word[i]):
      display[i]=guess


  if("_" not in display):
    print(display)
    print("You have guessed the word correctly!! You Win!!\n")

    print("The word was",chosen_word)
    print(display)
    break



  if guess not in chosen_word:

    lives -= 1
    art += 1
    print("You guessed it wrong!!\no")

    print("You have",lives,"lives left\n")


    if(lives == 0):
      print(hangman[art])
      print("You have run out of lives, You loose")
      print("The word was",chosen_word)
      break

  print(hangman[art])
  print(display)
# Out:
# ['_', '_', '_', '_']
# Make a guess:s
# You guessed it wrong!!
# o
# You have 5 lives left
#
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# ...
# ['_', '_', '_', '_']
# Make a guess:n
# You guessed it wrong!!
# o
# You have 4 lives left
#
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# ...
# ['_', '_', '_', '_']
# Make a guess:a
# You guessed it wrong!!
# o
# You have 3 lives left
#
#
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# ...
# ['_', '_', '_', '_']
# Make a guess:t
#
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# ...
# ['t', '_', '_', '_']
# Make a guess:i
#
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# ...
# ['t', 'i', '_', '_']
# Make a guess:m
#
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# ...
# ['t', 'i', 'm', '_']
# Make a guess:e
# ['t', 'i', 'm', 'e']
# You have guessed the word correctly!! You Win!!
#
# The word was time
# ['t', 'i', 'm', 'e']
